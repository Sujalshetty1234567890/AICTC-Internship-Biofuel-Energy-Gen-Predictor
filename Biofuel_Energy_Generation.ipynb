# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emi_data= pd.read_csv("CO2 Emissions.csv")
gen_data= pd.read_excel("BIOFUEL PLANT DATA 1.xlsx")

# %%
gen_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Project Type                            526 non-null    object
#  1   City                                    525 non-null    object
#  2   County                                  517 non-null    object
#  3   Digester Type                           525 non-null    object
#  4   Animal/Farm Type(s)                     526 non-null    object
#  5   Cattle                                  12 non-null     float64
#  6   Dairy                                   421 non-null    float64
#  7   Poultry                                 13 non-null     float64
#  8   Swine                                   59 non-null     float64
#  9   Biogas Generation Estimate (cu-ft/day)  232 non-null    float64
# ...

# %%
gen_data.shape
# Out:
# (526, 15)

# %%
gen_data.head()
# Out:
#            Project Type       City    County           Digester Type  \
# 0            Farm Scale  Morrilton    Conway          Covered Lagoon
# 1            Farm Scale    Buckeye  Maricopa         Mixed Plug Flow
# 2            Farm Scale       Eloy     Pinal  Unknown or Unspecified
# 3  Centralized/Regional   Maricopa     Pinal            Complete Mix
# 4            Farm Scale  Gila Bend  Maricopa            Complete Mix
#
#   Animal/Farm Type(s)  Cattle    Dairy  Poultry   Swine  \
# 0               Swine     NaN      NaN      NaN  4200.0
# 1               Dairy     NaN  11760.0      NaN     NaN
# 2               Dairy     NaN   8800.0      NaN     NaN
# 3               Dairy     NaN  30000.0      NaN     NaN
# 4               Dairy     NaN  10000.0      NaN     NaN
#
#    Biogas Generation Estimate (cu-ft/day) Electricity Generated (kWh/yr)  \
# 0                               1814400.0                            NaN
# ...

# %%
gen_data.describe()
# Out:
#              Cattle         Dairy       Poultry          Swine  \
# count     12.000000    421.000000  1.300000e+01      59.000000
# mean    7509.166667   4133.014252  2.299231e+05   24796.983051
# std    12764.579157   5152.295435  3.154480e+05   45830.494267
# min       30.000000     30.000000  3.300000e+04      10.000000
# 25%      825.000000   1027.000000  8.000000e+04    4100.000000
# 50%     2450.000000   2500.000000  1.200000e+05    8640.000000
# 75%     5000.000000   5700.000000  1.600000e+05   25600.000000
# max    40000.000000  39000.000000  1.200000e+06  239200.000000
#
#        Biogas Generation Estimate (cu-ft/day)  \
# count                            2.320000e+02
# mean                             3.127576e+05
# std                              4.433939e+05
# min                              5.000000e+03
# 25%                              7.000000e+04
# 50%                              2.000000e+05
# 75%                              3.451500e+05
# ...

# %%
gen_data.isnull().sum()
# Out:
# Project Type                                0
# City                                        1
# County                                      9
# Digester Type                               1
# Animal/Farm Type(s)                         0
# Cattle                                    514
# Dairy                                     105
# Poultry                                   513
# Swine                                     467
# Biogas Generation Estimate (cu-ft/day)    294
# Electricity Generated (kWh/yr)            284
# Biogas End Use(s)                           8
# Receiving Utility                         274
# Total Emission Reductions (MTCO2e/yr)     127
# Awarded USDA Funding?                     399
# dtype: int64

# %%
emi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Vehicle Class                     7385 non-null   object
#  2   Engine Size(L)                    7385 non-null   float64
#  3   Cylinders                         7385 non-null   int64
#  4   Transmission                      7385 non-null   object
#  5   Fuel Type                         7385 non-null   object
#  6   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  7   Fuel Consumption Comb (mpg)       7385 non-null   int64
#  8   CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 519.4+ KB

# %%
emi_data.shape
# Out:
# (7385, 9)

# %%
emi_data.head()
# Out:
#     Make Vehicle Class  Engine Size(L)  Cylinders Transmission Fuel Type  \
# 0  ACURA       COMPACT             2.0          4          AS5         Z
# 1  ACURA       COMPACT             2.4          4           M6         Z
# 2  ACURA       COMPACT             1.5          4          AV7         Z
# 3  ACURA   SUV - SMALL             3.5          6          AS6         Z
# 4  ACURA   SUV - SMALL             3.5          6          AS6         Z
#
#    Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 0                               8.5                           33
# 1                               9.6                           29
# 2                               5.9                           48
# 3                              11.1                           25
# 4                              10.6                           27
#
#    CO2 Emissions(g/km)
# 0                  196
# 1                  221
# 2                  136
# 3                  255
# ...

# %%
emi_data.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption Comb (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         10.975071
# std          1.354170     1.828307                          2.892506
# min          0.900000     3.000000                          4.100000
# 25%          2.000000     4.000000                          8.900000
# 50%          3.000000     6.000000                         10.600000
# 75%          3.700000     6.000000                         12.600000
# max          8.400000    16.000000                         26.100000
#
#        Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# count                  7385.000000          7385.000000
# mean                     27.481652           250.584699
# std                       7.231879            58.512679
# min                      11.000000            96.000000
# 25%                      22.000000           208.000000
# ...

# %%
emi_data.isnull().sum()
# Out:
# Make                                0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
gen_data.plot.scatter(x='Biogas Generation Estimate (cu-ft/day)', y='Total Emission Reductions (MTCO2e/yr)')
plt.show()

# %%
gen_data.boxplot(column='Total Emission Reductions (MTCO2e/yr)')
plt.show()

# %%
emi_data.boxplot(column='CO2 Emissions(g/km)')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emi_data= pd.read_csv("CO2 Emissions.csv")
gen_data= pd.read_excel("BIOFUEL PLANT DATA 1.xlsx")

# %%
x= gen_data.drop('Total Emission Reductions (MTCO2e/yr)', axis=1)
y= gen_data['Total Emission Reductions (MTCO2e/yr)']

# %%
x
# Out:
#              Project Type  ... Awarded USDA Funding?
# 0              Farm Scale  ...                   NaN
# 1              Farm Scale  ...                   Yes
# 2              Farm Scale  ...                   NaN
# 3    Centralized/Regional  ...                   NaN
# 4              Farm Scale  ...                   NaN
# ..                    ...  ...                   ...
# 521            Farm Scale  ...                   Yes
# 522            Farm Scale  ...                   NaN
# 523            Farm Scale  ...                   NaN
# 524            Farm Scale  ...                   NaN
# 525            Farm Scale  ...                   NaN
#
# [526 rows x 14 columns]

# %%
y
# Out:
# 0        4482.755303
# 1       14030.128975
# 2       98999.890159
# 3      337499.625540
# 4      100569.493399
#            ...
# 521              NaN
# 522              NaN
# 523              NaN
# 524              NaN
# 525              NaN
# Name: Total Emission Reductions (MTCO2e/yr), Length: 526, dtype: float64

# %%
x_Train,x_Test,y_Train,y_Test= train_test_split(x,y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()
