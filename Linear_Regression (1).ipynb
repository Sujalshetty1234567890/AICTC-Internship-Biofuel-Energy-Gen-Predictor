# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
gd = pd.read_excel("BIOFUEL PLANT DATA 2.xlsx")

# %%
fd = gd.dropna(subset=["Biogas Generation Estimate (cu-ft/day)"])

# %%
x = pd.DataFrame(fd['Dairy'])
y = fd['Biogas Generation Estimate (cu-ft/day)']

# %%
x_Train,x_Test,y_Train,y_Test= train_test_split(x,y, test_size=0.15, random_state=360)

# %%
model = LinearRegression()
model.fit(x_Train,y_Train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_Test)

# %%
mse = mean_squared_error(y_Test, y_pred)
r2 = r2_score(y_Test, y_pred)
print ("Mean Squared Error:", mse)
print ("R-squared:", r2)
# Out:
# Mean Squared Error: 142910328390.69223
# R-squared: 0.5802337586237378

# %%
plt.scatter(x_Test, y_Test, color='blue', label='Test Data')
plt.plot(x_Test, y_pred, color="red", label='Regression Line')
plt.xlabel('Dairy')
plt.ylabel("Energy Consumption (kWh)")
plt.legend()
plt.title('Biogas Generated Prediction using Simple Linear Regression')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
ed = pd.read_csv("CO2 Emissions.csv")

# %%
x = pd.DataFrame(ed['Fuel Consumption Comb (L/100 km)'])
y = ed['CO2 Emissions(g/km)']

# %%
x_Train,x_Test,y_Train,y_Test= train_test_split(x,y, test_size=0.2, random_state=360)

# %%
model = LinearRegression()
model.fit(x_Train,y_Train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_Test)

# %%
mse = mean_squared_error(y_Test, y_pred)
r2 = r2_score(y_Test, y_pred)
print ("Mean Squared Error:", mse)
print ("R-squared:", r2)
# Out:
# Mean Squared Error: 520.8206733872905
# R-squared: 0.8447757682593688

# %%
plt.scatter(x_Test, y_Test, color='blue', label='Test Data')
plt.plot(x_Test, y_pred, color="red", label='Regression Line')
plt.xlabel('Fuel Consumption Comb (L/100 km)')
plt.ylabel("CO2 Emissions(g/km)")
plt.legend()
plt.title('CO2 Emission compared to Biofuel Prediction using Simple Linear Regression')
plt.show()
